# %%
import ddq_circuit_generators as scg

# %%
import stim
c = stim.Circuit()
c.append("X", 0)
c.append("M", 0)
c.compile_sampler().sample(shots=1)

circ = stim.Circuit('''
H 0
CNOT 0 1
M 0 1
DETECTOR rec[-1] rec[-2]
''').compile_detector_sampler().sample(shots=100)

# %%
circ
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...
