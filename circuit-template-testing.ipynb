# %%
import sys
import stim
sys.path.append("../")

from plotting.simulation_plotters import *
from plotting.bads_plotters import *
from experiments.simulation_experiments import *
from helpers.helpers import *

import generators.rsc_z_generator as scgz

# %reload_ext autoreload
# %aimport plotting.simulation_plotters
# %aimport helpers.helpers
# %aimport generators.rsc_z_generator
# %aimport experiments.simulation_experiments
# %autoreload 2

# %%
circ = scgz.surface_code_circuit_string(3, 2, 0.0)

# %%
sim = uniform_homogeneous_noise_model_simulation_distance([3], [0.0001])
sim = homogeneous_noise_model_simulation(distance=[3], p_values=[0.0001], p_defect_values=[0.0001], defect_type=['center data'])
sim = heterogeneous_noise_model_simulation(distance=[3], p_sigma_values=[0.000001])
sim = heterogeneous_noise_model_with_defect_simulation(distance=[3], scalar=0.0006, p_defect_values=[0.0001], defect_type=['center data'])
# concat_stats_df(sim)
# Out:
# 3
# Completed d=3 - Runtime: 1.2311 seconds
#
# Completed d=3 - Runtime: 1.2770 seconds
#
# Completed d=3 - Runtime: 1.5231 seconds
#
# Completed d=3 - Runtime: 1.5190 seconds
